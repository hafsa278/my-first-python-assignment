# %% [markdown]
# <a href="https://colab.research.google.com/github/hafsa278/my-first-python-assignment/blob/master/untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = 45;
type(number)
# Out:
# int

# %%
age = int(input("enter your age"))
# Out:
# enter your age45

# %%
name = input("enter you name")
# Out:
# enter you namehafsa

# %%
age
# Out:
# 25

# %%
name
# Out:
# 'hafsa '

# %%
profession = input("enter your profession")
# Out:
# enter your professionTeacher

# %%
profession
# Out:
# 'Teacher'

# %%
Gender = input("enter your gender")
# Out:
# enter your genderfemale

# %%
Gender
# Out:
# 'female'

# %%
# Out:
# hafasa khursheedtttt

# %%
myName = input("enter your name ")
# Out:
# enter your name usman

# %%
myName
# Out:
# 'usman'

# %%
x = input("enter bool value")
# Out:
# enter bool valuetrue

# %%
type(x)
# Out:
# str
